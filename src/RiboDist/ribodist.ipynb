# %%
# %matplotlib tk

import sys
import re
from os.path import exists

import numpy as np
import pandas as pd
import starfile as sf

from sklearn.cluster import AgglomerativeClustering
import scipy.interpolate as spin

import matplotlib as mpl
import matplotlib.pyplot as plt

# np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ## Function definitions

# %%
def get_ribo_from_star(star_file):
    pixel_size_nm = sf.read(star_file)['optics'].rlnImagePixelSize.values[0] * 0.1
    ribo_star = sf.read(star_file)
    ribo_star['particles']['rlnTS'] = [int(i.split('/')[1].split('_')[-1]) for i in list(ribo_star['particles'].rlnImageName.values)]
    TS_list = pd.unique(ribo_star['particles'].rlnTS)
    
    return ribo_star, TS_list, pixel_size_nm

# %%
def get_coords(star_df_in, TS, model_bin, star_bin):
    ribo = star_df_in[star_df_in.rlnTS==TS][['rlnCoordinateX', 'rlnCoordinateY', 'rlnCoordinateZ']].to_numpy() * star_bin / model_bin
    
    return ribo

# %%
def get_model(model_file):
    model = np.loadtxt(model_file)
    model_size = len(model)
    model = model[model[:,2].argsort()]
    
    return model

# %%
def segment_surfaces(model_in):
    ac = AgglomerativeClustering(n_clusters=2, linkage="single")
    ac.fit(model)

    labels = ac.labels_
    model_lower = np.squeeze(model[np.argwhere(labels==0)], axis=1)
    model_upper = np.squeeze(model[np.argwhere(labels==1)], axis=1)
    
    return labels, model_lower, model_upper

# %%
def interpolator(coords_in, upper_in, lower_in, N):
    x_top = np.linspace(np.min(upper_in[:,0]), np.max(upper_in[:,0]), N)
    y_top = np.linspace(np.min(upper_in[:,1]), np.max(upper_in[:,1]), N)
    XX, YY = np.meshgrid(x_top, y_top)

    x_bot = np.linspace(np.min(lower_in[:,0]), np.max(lower_in[:,0]), N)
    y_bot = np.linspace(np.min(lower_in[:,1]), np.max(lower_in[:,1]), N)
    xx, yy = np.meshgrid(x_bot, y_bot)


    itp_top = spin.LinearNDInterpolator(list(zip(upper_in[:,0], upper_in[:,1])), upper_in[:,2])
    itp_bot = spin.LinearNDInterpolator(list(zip(lower_in[:,0], lower_in[:,1])), lower_in[:,2])
    ZZ = itp_top(XX, YY)
    zz = itp_bot(xx, yy)

    interped_top = np.dstack((XX, YY, ZZ))
    interped_bot = np.dstack((xx, yy, zz))
    
    to_edge = np.empty((len(coords_in), 2))
    for idx, point in enumerate(coords_in):
        to_edge[idx] = [np.nanmin(np.linalg.norm(interped_top - point, axis=2)), np.nanmin(np.linalg.norm(interped_bot - point, axis=2))]
    
    return interped_top, interped_bot, to_edge

# %% [markdown]
# ## Getting model / ribosome coords

# %%
model_bin = 8
star_bin = 2

model_file_format = "Position_<TS>_bin8_filtered2.txt"

# %%
star_file = "ribosomes/bin2_postM_refinement_conv.star"
ribo_star, TS_list, pixel_size_nm = get_ribo_from_star(star_file)

# %% [markdown]
# ## Loop through list of TS

# %%
for _, curr_ts in enumerate(TS_list):
    model_file = re.sub("<TS>", str(curr_ts), model_file_format)
    try: 
        assert(exists(model_file))
    except:
        print(f"WARNING: {model_file} doesn't exist. TS{curr_ts} skipped.")
        continue
        
    ribo = get_coords(ribo_star['particles'], curr_ts, model_bin, star_bin)
    model = get_model(model_file)

    #     Segmentation of surfaces
    labels, model_upper, model_lower = segment_surfaces(model)
    
    #     Plane interpolation
    interped_top, interped_bot, to_edge = interpolator(ribo, model_upper, model_lower, 100)
    
    #     Aggregation of data
    df = pd.DataFrame(columns=["x", "y", "z", "to_top", "to_bottom"])
    df.x = ribo[:, 0]
    df.y = ribo[:, 1]
    df.z = ribo[:, 2]
    df.to_top = to_edge[:, 0]
    df.to_bottom = to_edge[:, 1]
    df["to_any_edge"] = df[["to_top", "to_bottom"]].values.min(1)
    
#     Update of star-DataFrame
    ribo_star['particles'].loc[ribo_star['particles'].rlnTS==curr_ts, 'rlnDistToEdge_nm'] = df.to_any_edge.to_numpy() * pixel_size_nm * model_bin / star_bin

# %%
pd.set_option('display.max_rows', 10)
ribo_star['particles'][~ribo_star['particles'].rlnDistToEdge_nm.isnull()]
# Out:
#        rlnCoordinateX  rlnCoordinateY  rlnCoordinateZ  rlnAngleRot  \
# 8118        1337.2490        400.4035        535.7270    126.46280
# 8119        1784.5280       1884.7200        457.0119    -11.46472
# 8120        1313.0810        825.5162        861.7173   -174.27860
# 8121        1617.4870        190.4373        189.2904    -68.75554
# 8122        1188.8830        460.2473        817.0438    163.07020
# ...               ...             ...             ...          ...
# 13375       1001.0370       1448.7940        371.2605     68.80367
# 13376        794.2349       1206.1050        420.6743   -153.80690
# 13377       1177.6690        203.5547        395.1078    -90.39685
# 13378        926.5816       1121.4620        506.4562     21.47708
# 13379        932.9862       1774.6760        352.6313   -161.20890
#
#        rlnAngleTilt  rlnAnglePsi  \
# 8118       20.26509    -97.67905
# 8119      167.08530     59.68486
# 8120       22.51733    -69.87370
# 8121      148.56390   -117.83550
# 8122       64.31494    145.93260
# ...             ...          ...
# 13375      80.41988    129.98090
# 13376     113.10310     82.39798
# 13377     142.08800     93.44049
# 13378      84.77400   -162.28090
# 13379     123.34520   -136.15940
#
#                                             rlnImageName  \
# 8118   Particles/Position_36/Position_36_ribo06_00000...
# 8119   Particles/Position_36/Position_36_ribo06_00000...
# 8120   Particles/Position_36/Position_36_ribo06_00000...
# 8121   Particles/Position_36/Position_36_ribo06_00000...
# 8122   Particles/Position_36/Position_36_ribo06_00000...
# ...                                                  ...
# 13375  Particles/Position_99/Position_99_ribo06_00005...
# 13376  Particles/Position_99/Position_99_ribo06_00005...
# 13377  Particles/Position_99/Position_99_ribo06_00005...
# 13378  Particles/Position_99/Position_99_ribo06_00005...
# 13379  Particles/Position_99/Position_99_ribo06_00005...
#
#                                              rlnCtfImage  rlnRandomSubset  \
# 8118   Particles/Position_36/Position_36_ribo06_00000...                2
# 8119   Particles/Position_36/Position_36_ribo06_00000...                1
# 8120   Particles/Position_36/Position_36_ribo06_00000...                2
# 8121   Particles/Position_36/Position_36_ribo06_00000...                1
# 8122   Particles/Position_36/Position_36_ribo06_00000...                2
# ...                                                  ...              ...
# 13375  Particles/Position_99/Position_99_ribo06_00005...                2
# 13376  Particles/Position_99/Position_99_ribo06_00005...                1
# 13377  Particles/Position_99/Position_99_ribo06_00005...                2
# 13378  Particles/Position_99/Position_99_ribo06_00005...                1
# 13379  Particles/Position_99/Position_99_ribo06_00005...                1
#
#        rlnOpticsGroup  rlnTS  rlnDistToEdge_nm
# 8118                1     36        174.940150
# 8119                1     36        183.381995
# 8120                1     36         59.474072
# 8121                1     36         65.112862
# 8122                1     36         86.963044
# ...               ...    ...               ...
# 13375               1     99         37.302906
# 13376               1     99         32.425480
# 13377               1     99         51.280616
# 13378               1     99         74.079435
# 13379               1     99         15.871455
#
# [1957 rows x 12 columns]

# %% [markdown]
# ## Write out to star file

# %%
new_star_path = "mystar.star"

sf.write(ribo_star, new_star_path, overwrite=True)

# %% [markdown]
# ## Visualisation

# %%
N = 50

closest_points = df.sort_values(by="to_top").head(N)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.plot_trisurf(model_lower[:,0], model_lower[:,1], model_lower[:,2], color='b', antialiased=True)
ax.plot_trisurf(model_upper[:,0], model_upper[:,1], model_upper[:,2], color='g', antialiased=True)
ax.scatter(ribo[:,0], ribo[:,1], ribo[:,2], c=df.to_any_edge, cmap="inferno_r")
plt.tight_layout()

# %%
closest_points
# Out:
#               x           y           z     to_top   to_bottom  to_any_edge
# 188  216.673850   89.941350  228.716150  10.703467  137.452438    10.703467
# 189  210.675425  382.159250  230.072075  12.712387  143.912875    12.712387
# 57   172.263650  269.428750  242.209650  12.801857  145.673725    12.801857
# 247  285.458250  419.759250  206.983050  13.482779  140.743655    13.482779
# 82   154.111425   55.981950  241.114250  13.918548  131.515485    13.918548
# 279  264.400250  458.705750  210.229725  14.168940  135.552078    14.168940
# 396  140.872075  426.530250  247.298850  14.806094  136.340569    14.806094
# 273   78.655275  335.083750  264.476500  15.941909  143.036335    15.941909
# 255  288.012500  167.659050  206.393300  16.015900  136.614513    16.015900
# 538  196.763850  227.347850  232.339275  16.052000  140.183574    16.052000
# 184   88.788175  394.220000  261.307500  16.356237  136.764213    16.356237
# 269  250.363250  235.133050  217.862025  16.738628  140.782250    16.738628
# 398  156.445200   89.392750  239.522700  16.800237  130.694468    16.800237
# 498  231.325600  387.421750  219.879600  16.884928  139.689878    16.884928
# 252  347.507000  219.081075  189.359250  18.076530  138.707917    18.076530
# 256  325.459750  314.180750  194.489650  19.717457  141.271166    19.717457
# 187  150.534375  379.969250  239.500800  20.226596  135.691254    20.226596
# 215   87.464125  418.302750  257.298000  20.377202  130.672209    20.377202
# 203  237.270800  255.131500  217.513100  20.680915  137.983288    20.680915
# 254  215.694650   69.471150  217.153775  20.858314  126.047049    20.858314
# 283  415.042000  452.700750  160.392300  21.291864  131.657952    21.291864
# 512  301.031000  189.100550  197.304525  21.864739  132.453861    21.864739
# 38   180.757500  183.877500  229.182900  22.869969  130.344596    22.869969
# 414  417.938750  217.551150  163.789050  23.405134  133.328484    23.405134
# 240   95.699475  293.751750  251.293000  23.635975  136.335320    23.635975
# 277  225.665400  188.171000  216.026150  23.854575  129.978683    23.854575
# 379  460.980750  285.804750  156.014925  24.161780  139.108531    24.161780
# 312  309.639750  247.327975  194.267900  24.610717  134.319210    24.610717
# 541   58.167400  383.716500  260.844250  25.525176  128.380940    25.525176
# 272  400.287500  447.738250  160.041600  25.804970  127.267138    25.804970
# 511  282.053750  405.388000  195.282025  26.092569  129.433026    26.092569
# 334  243.790875  424.926250  205.344325  26.192424  126.813622    26.192424
# 409  427.875000  234.946000  158.736425  26.766084  131.627897    26.766084
# 191  190.059650  102.696225  219.885825  27.034428  121.407241    27.034428
# 76   436.830500  427.410500  150.289075  27.135339  128.638639    27.135339
# 200  240.109375  358.625000  207.179725  27.581491  132.137569    27.581491
# 193  215.982625  347.335000  213.770275  27.907119  132.571260    27.907119
# 500  202.436625  212.585550  218.047375  28.178538  127.102098    28.178538
# 540  126.450400  409.401250  237.614925  28.291355  124.112522    28.291355
# 27   140.962900  439.385250  232.793325  28.302912  121.902131    28.302912
# 397  109.805750  435.274250  241.877575  28.660020  121.690521    28.660020
# 237   47.793300  346.833250  258.335500  30.558587  127.007851    30.558587
# 236  167.778525  208.800425  224.391350  30.939431  123.801050    30.939431
# 535  444.086500  397.898500  146.837625  30.983232  127.975859    30.983232
# 311  273.074750  351.051000  193.964100  31.963454  128.702595    31.963454
# 40   205.615000  308.306500  212.939450  32.048440  128.005581    32.048440
# 384  419.365500  423.408250  150.060400  32.258548  123.735627    32.258548
# 41   323.319250  243.690075  182.329400  32.315482  126.339152    32.315482
# 192  209.460200  162.876550  210.496625  33.206401  118.880207    33.206401
# 275  254.869250  293.674250  198.607775  33.783245  126.131496    33.783245
